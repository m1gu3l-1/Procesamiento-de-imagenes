# %%
# %matplotlib widget

# %%
"""Python script to read an image, resize it, and save it under a different name."""

import imageio.v3 as iio
import matplotlib.pyplot as plt
import skimage as ski
import ipympl
import numpy as np

# read in image
chair = iio.imread(uri="chair.jpg")

# resize the image
new_shape = (chair.shape[0] // 100, chair.shape[1] // 100, chair.shape[2])
resized_chair = ski.transform.resize(image=chair, output_shape=new_shape)
resized_chair = ski.util.img_as_ubyte(resized_chair)

# write out image
iio.imwrite(uri="resized_chair.jpg", image=resized_chair)

# display images
fig, ax = plt.subplots()
ax.imshow(chair)
fig, ax = plt.subplots()
ax.imshow(resized_chair)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# read input image
maize_roots = iio.imread(uri="maize-root-cluster.jpg")
maize_roots = np.array(maize_roots)

# display original image
fig, ax = plt.subplots()
ax.imshow(maize_roots)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
1# keep only high-intensity pixels
maize_roots[maize_roots < 128] = 0

# display modified image
fig, ax = plt.subplots()
ax.imshow(maize_roots)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
1# keep only high-intensity pixels
maize_roots[maize_roots < 128] = 0

# display modified image
fig, ax = plt.subplots()
ax.imshow(maize_roots)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# read input image
chair = iio.imread(uri="chair.jpg")

# display original image
fig, ax = plt.subplots()
ax.imshow(chair)

# convert to grayscale and display
gray_chair = ski.color.rgb2gray(chair)
fig, ax = plt.subplots()
ax.imshow(gray_chair, cmap="gray")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""Python script to load a color image as grayscale."""

# read input image, based on filename parameter
gray_chair = iio.imread(uri="chair.jpg", mode="L")

# display grayscale image
fig, ax = plt.subplots()
ax.imshow(gray_chair, cmap="gray")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""Python script to load a color image as grayscale."""

# read input image, based on filename parameter
sudoku1 = iio.imread(uri="sudoku.png", mode="L")
sudoku = np.array(sudoku1)
# display grayscale image
fig, ax = plt.subplots()
ax.imshow(sudoku1, cmap="gray")

sudoku[sudoku > 192] = 192
fig, ax = plt.subplots(ncols=1)
#ax[0].imshow(sudoku1, cmap="gray", vmin=0, vmax=255)
ax.imshow(sudoku, cmap="gray", vmin=0, vmax=255 )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
